# %%
import pandas as pd

# %%
df = pd.read_csv("dados.csv")

# %%
df.head(40)
# Out:
#                                                  Link            Tipo Valor  \
# 0   https://www.terabyteshop.com.br/produto/13445/...     Processador   999
# 1   https://www.kabum.com.br/produto/112990/proces...     Processador  1100
# 2   https://www.amazon.com.br/Processador-Intel-I5...     Processador  1110
# 3   https://www.terabyteshop.com.br/produto/20592/...       Placa Mãe   459
# 4   https://www.pontofrio.com.br/placa-mae-biostar...       Placa Mãe   699
# 5   https://www.submarino.com.br/produto/588487438...       Placa Mãe   439
# 6   https://www.terabyteshop.com.br/produto/21516/...         Memória   219
# 7   https://www.terabyteshop.com.br/produto/18657/...         Memória   269
# 8   https://www.terabyteshop.com.br/produto/18662/...         Memória   269
# 9   https://www.terabyteshop.com.br/produto/22281/...             SSD   160
# 10  https://www.terabyteshop.com.br/produto/7443/s...             SSD   189
# ...

# %%
types = df[df['Publico']==2000]['Tipo'].unique()

# %%
df2 = df[df['Publico']==5000]

# %%
#df2['Tipo'] = df2['Tipo'].apply(isHD)

# %%
df2
# Out:
#                                                  Link            Tipo  \
# 42  https://www.terabyteshop.com.br/produto/17256/...     Processador
# 43  https://www.kabum.com.br/produto/148903/proces...     Processador
# 44  https://www.inpower.com.br/processador-intel-c...     Processador
# 45  https://www.terabyteshop.com.br/produto/18208/...       Placa Mãe
# 46  https://www.netalfa.com.br/placa-mae-gigabyte-...       Placa Mãe
# 47  https://shopee.com.br/Placa-M%C3%A3e-Gigabyte-...       Placa Mãe
# 48  https://www.terabyteshop.com.br/produto/14614/...          Cooler
# 49  https://www.kabum.com.br/produto/202904/cooler...          Cooler
# 50  https://www.pichau.com.br/cooler-deepcool-gamm...          Cooler
# 51  https://www.terabyteshop.com.br/produto/18653/...         Memória
# 52  https://produto.mercadolivre.com.br/MLB-206791...         Memória
# 53  https://www.terabyteshop.com.br/produto/20058/...         Memória
# ...

# %%
print(df2.to_html(index=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Link</th>
#       <th>Tipo</th>
#       <th>Valor</th>
#       <th>Publico</th>
#       <th>Nome</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>https://www.terabyteshop.com.br/produto/17256/processador-intel-core-i5-11600k-39ghz-50ghz-turbo-11-geracao-6-cores-12-threads-lga-1200-bx8070811600k</td>
#       <td>Processador</td>
#       <td>1600</td>
#       <td>5000</td>
#       <td>Processador Intel Core i5 11600K 3.9GHz (5.0GHz Turbo), 11ª Geração, 6-Cores 12-Threads, LGA 1200, BX8070811600K</td>
#     </tr>
#     <tr>
#       <td>https://www.kabum.com.br/produto/148903/processador-intel-core-i5-11600k-11-geracao-3-9-ghz-4-9ghz-turbo-cache-12mb-6-nucleos-12-threads-lga-1200-video-integrado-bx8070811600k</td>
#       <td>Processador</td>
#       <td>1.560,00</td>
#       <td>5000</td>
# ...
